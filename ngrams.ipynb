# %% [markdown]
# <a href="https://colab.research.google.com/github/Sylamsh/nlp-practice/blob/main/ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import string

# %%
def make_words(lyrics):
  translator = str.maketrans("","", string.punctuation)
  lyrics_puntuations = lyrics.translate(translator)
  lyrics = lyrics_puntuations.lower().strip()
  return lyrics

# %%
def generate_sentence(next_word, n):
  if uniq_words.count(next_word) == 0:
    return "'" + next_word + "' does not exist in the given dataset"
  sentence = next_word
  for i in range(0, n):
    curr_word = next_word
    next_word = df.index[df[curr_word] == max(df[curr_word])][0]
    sentence = sentence + ' ' + next_word
  return sentence

# %%
# train_lyrics = """Do you know what's worth fighting for
# When it's not worth dying for?
# Does it take your breath away
# And you feel yourself suffocating?
# Does the pain weigh out the pride?
# And you look for a place to hide?
# Did someone break your heart inside?
# You're in ruins
# Did you try to live on your own
# When you burned down the house and home?
# Did you stand too close to the fire?
# Like a liar looking for forgiveness from a stone
# When it's time to live and let die
# And you can't get another try
# Something inside this heart has died
# You're in ruins
# When you're at the end of the road
# And you lost all sense of control
# And your thoughts have taken their toll
# When your mind breaks the spirit of your soul
# Your faith walks on broken glass
# And the hangover doesn't pass
# Nothing's ever built to last
# You're in ruins
# One, twenty one guns
# Lay down your arms
# Give up the fight
# One, twenty one guns
# Throw up your arms into the sky,
# You and I"""
train_lyrics="""So I was just checking my mechanical keyboard feel I know its been so long since I bought, but its just a check. Its good but I still didn't get used to the placement of the keys. I still make mistakes, just how I am with the piano. I dunno. I'm just not confident with it. Both piano and this keyboard. I know all you need is practice. But even then I have this overbearing feel of insecurity that'll never leave me. I think I still have the imposter syndrome. But Not as effective as it was before. May I'm still healing I need to give myself more time. I'm trying to do a lot but I dunno where it gets me. When I think about the future the practical answer I get it to start coding and master it. The answer also tells me what I'm doing right now is completey useless. The videos, the songs and that game development learning. These are the things that are just extra, side dishes. The main course is to code. I accept but I don't want to stop what I'm doing. I don't have to be hardcore, I just have to be consistent. I'll code every day even if the problem is not completely solved. I learnt that day how not to do. A theard in my brain looks into it for the next part of the day I will learn more, by the next day. 
I just have one thing to say to myself. Code consistently everyday. Make videos. Make songs. Learn how to make videogames. even start making games in the rear future. never give up hope. I know its a thin thread now. And I also know that I'll keep woking reagardless of my hope, coz thats how I am. Or I'll stop it all together. 
All the best kid
You will make it. You will make yourself proud. You will create a community around you. You will create music that you will love and moves many others. You make games that are gonna be sucessful and trend setters in the gaming history. You are make yourself proud. All the best man. All the very best. All this time, I hated luck or never obliged its existence, but now you read my words. Your consistent efferot will bring in the luck you never thought was gonna be possible. Your life will be better than ever. Not just better than never. But better than many other."""

# %%
train_lyrics = make_words(train_lyrics)
# test_lyrics, test_words = make_words(test_lyrics)

# %%
words = train_lyrics.strip().split()
uniq_words = sorted(list(set(words)))
df = pd.DataFrame(index=uniq_words)
for curr_word in uniq_words:
  col = []
  for next_word in uniq_words:
    col.append(train_lyrics.count(curr_word + ' ' + next_word) / train_lyrics.count(curr_word))
  df[curr_word] = col
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
generate_sentence('to', 10)
# Out:
# 'to be be be be be be be be be be'

# %%
words
# Out:
# ['so',
#  'i',
#  'was',
#  'just',
#  'checking',
#  'my',
#  'mechanical',
#  'keyboard',
#  'feel',
#  'i',
#  'know',
#  'its',
#  'been',
#  'so',
#  'long',
#  'since',
#  'i',
#  'bought',
#  'but',
#  'its',
#  'just',
#  'a',
#  'check',
#  'its',
#  'good',
#  'but',
#  'i',
#  'still',
#  'didnt',
#  'get',
#  'used',
#  'to',
#  'the',
#  'placement',
#  'of',
#  'the',
#  'keys',
#  'i',
#  'still',
#  'make',
#  'mistakes',
#  'just',
#  'how',
#  'i',
#  'am',
#  'with',
#  'the',
#  'piano',
#  'i',
#  'dunno',
#  'im',
#  'just',
#  'not',
#  'confident',
#  'with',
#  'it',
#  'both',
#  'piano',
#  'and',
#  'this',
#  'keyboard',
#  'i',
#  'know',
#  'all',
#  'you',
#  'need',
#  'is',
#  'practice',
#  'but',
#  'even',
#  'then',
#  'i',
#  'have',
#  'this',
#  'overbearing',
#  'feel',
#  'of',
#  'insecurity',
#  'thatll',
#  'never',
#  'leave',
#  'me',
#  'i',
#  'think',
#  'i',
#  'still',
#  'have',
#  'the',
#  'imposter',
#  'syndrome',
#  'but',
# ...
